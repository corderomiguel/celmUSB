# %% [markdown]
# <a href="https://colab.research.google.com/github/corderomiguel/celmUSB/blob/main/pensa/Grafos_Pensum_Proyecto_de_Grado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### <span style="color:#8B0000;font-family:Papirus">Contrucción del digrafo de la 0500 y asignación de Etiquetas</span>

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Creamos un digrafo vacío
M = nx.DiGraph()

# Agregamos los nodos el orden en el que se agregan es intencional para la visualización del grafo que
# utiliza los subsets para la distribución de las posiciones
M.add_nodes_from(["Geometría", "Matemática\n I", "Lenguaje\n I","Inglés I","Venezuela\n Siglo XXI\n I",
                  "Matemática\n II","Física I","Lenguaje\n II","Inglés II","Venezuela\n Siglo XXI\n II",
                  "Matemática\n III","Física II","Lenguaje\n III","Inglés III","Venezuela\n Siglo XXI\n III",
                  "Cálculo I","Álgebra I","Geometría\n I","Inglés para\n Matemáticos\n I",
                  "Cálculo II","Álgebra II","Geometría\n II","Inglés para\n Matemáticos\n II",
                  "Cálculo III","Álgebra III","Geometría\n III","Inglés para\n Matemáticos\n III",
                  "Análisis I","Matemáticas\n Discretas","Int. Teoría de\n Grupos","Estudios\n Generales\n I",
                  "Análisis\n II","Topología. y\n Geometría\n I","Int. a las\n Probabilidades",
                  "Int. Teoría\n de Anillos","Servicio\n Comunitario","Análisis\n III",
                  "Int. a los\n Procesos\n Estocásticos.","Estudios\n Generales\n II","Análisis\n IV",
                  "Ecua.\n Diferenc. y\n Aplicaciones\n I","Electiva de\n Área (Proba y\n estadística)","Estudios\n Generales\n III",
                  "Análisis\n V","Combinatoria","Algoritmos y\n Estructuras\n I","Lab. de\n Algoritmos y\n Estructuras\n I",
                  "Análisis\n VI","Topología y\n Geometría\n II","Algoritmos y\n Estructuras\n II",
                  "Lab. de\n Algoritmos y\n Estructuras\n II","Estudios\n Generales\n IV","Proyecto de\n Grado I", "Proyecto de\n Grado II",
                  "Proyecto de\n Grado III","Electiva de\n Área\n Matemática\n Discreta","Ecuc. Diferenc y\n Aplicaciones\n II", "Estudios\n Generales\n V",
                  "Electiva\n Matemática\n I", "Electiva\n Matemática\n II", "Estudios\n Generales\n VI"])

# Agregamos los lados con peso, en este caso el peso representa los trimestres entre materias
M.add_weighted_edges_from([("Matemática\n I","Matemática\n II",1),("Matemática\n I","Física I",1),("Inglés I","Inglés II",1),("Lenguaje\n I","Lenguaje\n II",1),
                  ("Venezuela\n Siglo XXI\n I","Venezuela\n Siglo XXI\n II",1),("Matemática\n II","Matemática\n III",1),("Física I","Física II",1),
                  ("Inglés II","Inglés III",1),("Lenguaje\n II","Lenguaje\n III",1),("Venezuela\n Siglo XXI\n II","Venezuela\n Siglo XXI\n III",1),
                  ("Matemática\n III","Cálculo I",1), ("Matemática\n III","Álgebra I",1),("Matemática\n III","Geometría\n I",1),("Inglés III","Inglés para\n Matemáticos\n I",1),
                  ("Lenguaje\n III","Estudios\n Generales\n I",1),("Venezuela\n Siglo XXI\n III","Estudios\n Generales\n I",1),("Cálculo I","Cálculo II",1),
                  ("Álgebra I","Álgebra II",1),("Geometría\n I","Geometría\n II",1),("Inglés para\n Matemáticos\n I","Inglés para\n Matemáticos\n II",1),
                  ("Estudios\n Generales\n I","Estudios\n Generales\n II",1),("Cálculo II","Cálculo III",1),("Álgebra II","Álgebra III",1),("Geometría\n II","Geometría\n III",1),
                  ("Inglés para\n Matemáticos\n II","Inglés para\n Matemáticos\n III",1),("Estudios\n Generales\n II","Estudios\n Generales\n III",1),
                  ("Cálculo III","Análisis I",1),("Álgebra III","Matemáticas\n Discretas",1),("Álgebra III","Int. Teoría de\n Grupos",1),
                  ("Estudios\n Generales\n III","Estudios\n Generales\n IV",1),("Análisis I","Análisis\n II",1),("Análisis I","Topología. y\n Geometría\n I",1),
                  ("Matemáticas\n Discretas","Int. a las\n Probabilidades",1),("Matemáticas\n Discretas","Combinatoria",1),("Matemáticas\n Discretas","Algoritmos y\n Estructuras\n I",1),
                  ("Matemáticas\n Discretas","Lab. de\n Algoritmos y\n Estructuras\n I",1),("Int. Teoría de\n Grupos","Int. Teoría\n de Anillos",1),
                  ("Estudios\n Generales\n IV","Estudios\n Generales\n V",1),("Análisis\n II","Análisis\n III",1),("Topología. y\n Geometría\n I","Ecua.\n Diferenc. y\n Aplicaciones\n I",1),
                  ("Int. a las\n Probabilidades","Int. a los\n Procesos\n Estocásticos.",1),("Estudios\n Generales\n V","Estudios\n Generales\n VI",1),("Análisis\n III","Análisis\n IV",1),
                  ("Int. a los\n Procesos\n Estocásticos.","Electiva de\n Área (Proba y\n estadística)",1),("Análisis\n III","Ecua.\n Diferenc. y\n Aplicaciones\n I",1),
                  ("Análisis\n IV","Análisis\n V",1),("Ecua.\n Diferenc. y\n Aplicaciones\n I","Topología y\n Geometría\n II",1),("Análisis\n V","Análisis\n VI",1),
                  ("Combinatoria","Electiva de\n Área\n Matemática\n Discreta",1),("Algoritmos y\n Estructuras\n I","Algoritmos y\n Estructuras\n II",1),
                  ("Lab. de\n Algoritmos y\n Estructuras\n I","Lab. de\n Algoritmos y\n Estructuras\n II",1),
                  ("Proyecto de\n Grado I","Proyecto de\n Grado II",1),("Proyecto de\n Grado II","Proyecto de\n Grado III",1)])
# Etiquetas de los lados
etiquetas ={}
for item in list(M.edges()):
    etiquetas[item]=1

# Posiciones de los nodos 
pos={"Geometría": ([0 , 1.25]), 
     "Matemática\n I": ([0 , 1]),  
     "Inglés I": ([0 , 0.5]),
     "Lenguaje\n I": ([0 , 0.25]),
     "Venezuela\n Siglo XXI\n I": ([0 , 0]), 
     "Matemática\n II": ([2 , 1]), 
     "Física I": ([2 , 0.75]),  
     "Inglés II": ([2 , 0.5]), 
     "Lenguaje\n II": ([2 , 0.25]),
     "Venezuela\n Siglo XXI\n II": ([2 , 0]), 
     "Matemática\n III": ([4 , 1]), 
     "Física II": ([4 , 0.75]), 
     "Inglés III": ([4 , 0.5]),
     "Lenguaje\n III": ([4, 0.25]), 
     "Venezuela\n Siglo XXI\n III": ([4 , 0]), 
     "Cálculo I": ([6 , 1.5]), 
     "Álgebra I": ([6 , 1.25]), 
     "Geometría\n I": ([6 , 1]), 
     "Inglés para\n Matemáticos\n I": ([6 , 0.5]), 
     "Cálculo II": ([8 , 1.5]), 
     "Álgebra II": ([8 , 1.25]), 
     "Geometría\n II": ([8 , 1]), 
     "Inglés para\n Matemáticos\n II": ([8 , 0.5]), 
     "Cálculo III": ([10 , 1.5]), 
     "Álgebra III": ([10 , 1.25]), 
     "Geometría\n III": ([10 , 1]), 
     "Inglés para\n Matemáticos\n III": ([10 , 0.5]), 
     "Análisis I": ([12 , 1.5]), 
     "Matemáticas\n Discretas": ([12 , 1.25]), 
     "Int. Teoría de\n Grupos": ([12 , 1]), 
     "Estudios\n Generales\n I": ([12 , 0]), 
     "Análisis\n II": ([14 , 1.5]), 
     "Topología. y\n Geometría\n I": ([14 , 1.25]), 
     "Int. a las\n Probabilidades": ([14 , 1]), 
     "Int. Teoría\n de Anillos": ([14 , 0.75]), 
     "Servicio\n Comunitario": ([14 , 0.5]), 
     "Análisis\n III": ([16 , 1.5]), 
     "Int. a los\n Procesos\n Estocásticos.": ([16 , 1.25]), 
     "Estudios\n Generales\n II": ([16 , 0]), 
     "Análisis\n IV": ([18 , 1.5]), 
     "Ecua.\n Diferenc. y\n Aplicaciones\n I": ([18 , 1.25]), 
     "Electiva de\n Área (Proba y\n estadística)": ([18 , 1]), 
     "Estudios\n Generales\n III": ([18 , 0]), 
     "Análisis\n V": ([20 , 1.5]), 
     "Combinatoria": ([20 , 1.25]), 
     "Algoritmos y\n Estructuras\n I": ([20 , 1]), 
     "Lab. de\n Algoritmos y\n Estructuras\n I": ([20 , 0.75]), 
     "Análisis\n VI": ([22 , 1.5]), 
     "Topología y\n Geometría\n II": ([22 , 1.25]), 
     "Algoritmos y\n Estructuras\n II": ([22 , 1]), 
     "Lab. de\n Algoritmos y\n Estructuras\n II": ([22 , 0.75]), 
     "Estudios\n Generales\n IV": ([22 , 0]), 
     "Proyecto de\n Grado I": ([24 , 1]), 
     "Proyecto de\n Grado II": ([26,1]),
     "Proyecto de\n Grado III": ([28,1]),
     "Electiva de\n Área\n Matemática\n Discreta": ([26 , 1.5]), 
     "Ecuc. Diferenc y\n Aplicaciones\n II": ([26 , 1.25]), 
     "Estudios\n Generales\n V":([26 , 0]), 
     "Electiva\n Matemática\n I": ([28 , 1.5]), 
     "Electiva\n Matemática\n II": ([28 , 1.25]), 
     "Estudios\n Generales\n VI":([28 , 0])}

# Cambiamos las posiciones del texto de los nombres de los nodos
pos_nombres=copy.deepcopy(pos)
for n in pos_nombres: 
    pos_nombres[n][1] += 0.08

# %%
plt.figure(figsize=(17,10))   
nx.draw_networkx_nodes(M, pos, nodelist=M.nodes,node_color="cyan",node_size=150)
nx.draw_networkx_nodes(M, pos, nodelist=["Int. Teoría\n de Anillos", "Proyecto de\n Grado I","Análisis\n VI","Proyecto de\n Grado II",
                                         "Ecuc. Diferenc y\n Aplicaciones\n II","Proyecto de\n Grado III"],node_color="blue",node_size=150)
nx.draw_networkx_nodes(M, pos, nodelist=["Electiva de\n Área\n Matemática\n Discreta", "Algoritmos y\n Estructuras\n II",
                                         "Lab. de\n Algoritmos y\n Estructuras\n II","Estudios\n Generales\n VI"],node_color="orange",node_size=150)
nx.draw_networkx_edges(M,pos,M.edges)
nx.draw_networkx_labels(M, pos=pos_nombres, font_size=8)
nx.draw_networkx_edge_labels(M, pos=pos, edge_labels=etiquetas)  
plt.title("Materias de Lic. En Matemática 0500\n Modalidad Proyecto de Grado")
plt.axis("off")
plt.show()

# %% [markdown]
# Vale aclarar varios puntos:
# * El camino de "Estudio General 1" a "Estudio General 6" no existe realmente pues no hay tal relación entre ellos, sin embargo, es regla en la USB que los estudios generales se vean uno por trimestre, y solo después de haber aprobado "Sociales III" (o "Venezuela en el siglo XXI III") y "Lenguaje III". Por esta razón se representa tal normativa como un camino.
#
# * El camino de "Proyecto de Grado I" a "Proyecto de Grado III" si bien no tiene una materia como requisito, se ubica desde la última materia en el camino más largo, por ser la última actividad que realiza un estudiante en la carrera.
#
# * El "Servicio Comunitario", "Elect. Mate", "Elec. Matem" tampoco tienen una materia como requisito, pero deben cumplir ciertas condiciones para su inscripción, que a grosso modo es haber aprobado la mitad de la carrera.
